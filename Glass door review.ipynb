# %%
import pandas as pd
import numpy as np
import amatplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("../DataSets/Glassdoor companies review dataset.csv")

# %%
df
# Out:
#       timestamp       id                                            company  \
# 0    2023-11-01  1311218                                        Brightlands
# 1    2023-12-14  3097968  Ordine dei Medici Chirurghi e Odontoiatri Prov...
# 2    2023-11-01  4310888                                      F&C Engineers
# 3    2023-10-31  3034737                                 Minuteman Mortgage
# 4    2023-11-01  1385015                                   Fathom Computing
# ..          ...      ...                                                ...
# 995  2023-11-01  1438594                                              Timuz
# 996  2023-11-01  1550280                                      Midwest Arbor
# 997  2023-11-01   253909                      HintonBurdick CPAs & Advisors
# 998  2023-11-02   782441    Orthopedic & Sports Physical Therapy Associates
# 999  2023-11-01   924849                                              A.Hak
#
#      ratings_overall           details_size  details_founded  \
# 0                3.8    51 to 200 Employees              NaN
# 1                4.0                Unknown              NaN
# 2                4.0    51 to 200 Employees           2004.0
# 3                4.1      1 to 50 Employees           2018.0
# 4                5.0      1 to 50 Employees              NaN
# ..               ...                    ...              ...
# 995              4.4    51 to 200 Employees              NaN
# 996              2.0    51 to 200 Employees           1993.0
# 997              4.8    51 to 200 Employees           1975.0
# 998              4.3    51 to 200 Employees              NaN
# 999              4.0  501 to 1000 Employees           1963.0
#
#                 details_type country_code company_type  \
# 0          Company - Private           NL      Private
# 1           Company - Public           IT       Public
# 2          Company - Private           US      Private
# 3                    Unknown           IN        Other
# 4          Company - Private           US      Private
# ..                       ...          ...          ...
# 995        Company - Private           IN      Private
# 996        Company - Private           US      Private
# 997  Private Practice / Firm           US      Private
# 998        Company - Private           US      Private
# 999        Company - Private           NL      Private
#
#                                               url_jobs  ...  \
# 0    https://www.glassdoor.com/Jobs/Brightlands-Job...  ...
# 1    https://www.glassdoor.com/Jobs/Ordine-dei-Medi...  ...
# 2    https://www.glassdoor.com/Jobs/F-and-C-Enginee...  ...
# 3    https://www.glassdoor.com/Jobs/Minuteman-Mortg...  ...
# 4    https://www.glassdoor.com/Jobs/Fathom-Computin...  ...
# ..                                                 ...  ...
# 995  https://www.glassdoor.com/Jobs/Timuz-Jobs-E143...  ...
# 996  https://www.glassdoor.com/Jobs/Midwest-Arbor-J...  ...
# 997  https://www.glassdoor.com/Jobs/HintonBurdick-C...  ...
# 998  https://www.glassdoor.com/Jobs/Orthopedic-and-...  ...
# 999  https://www.glassdoor.com/Jobs/A-Hak-Jobs-E924...  ...
#
#     interview_difficulty interviews_count benefits_count jobs_count  \
# 0                    NaN                0            4.0          0
# 1                    3.0                1            NaN          0
# 2                    NaN                0            2.0          1
# 3                    NaN                0            NaN          0
# 4                    2.0                1            NaN          0
# ..                   ...              ...            ...        ...
# 995                  3.0                1            5.0          0
# 996                  2.0                1            NaN          0
# 997                  3.5                3            4.0          0
# 998                  NaN                0            NaN          3
# 999                  2.3                3            4.0        101
#
#                                                 photos photos_count  \
# 0                                                  NaN          NaN
# 1                                                  NaN          NaN
# 2                                                  NaN          NaN
# 3                                                  NaN          NaN
# 4                                                  NaN          NaN
# ..                                                 ...          ...
# 995                                                NaN          NaN
# 996  https://media.glassdoor.com/lst2x/45/2b/0a/3a/...          1.0
# 997  https://media.glassdoor.com/lst2x/37/1d/0e/51/...          1.0
# 998                                                NaN          NaN
# 999  https://media.glassdoor.com/lst2x/924849/a-hak...          8.0
#
#                                                    faq reviews_count  \
# 0    [{"answers":["{\"snippet\":\"Good company cult...             9
# 1                                                  NaN             1
# 2    [{"answers":["{\"snippet\":\"Great team enviro...             3
# 3    [{"answers":["{\"snippet\":\"Absolute only neg...             3
# 4                                                  NaN             1
# ..                                                 ...           ...
# 995  [{"answers":["{\"snippet\":\"Career Opportunit...             9
# 996  [{"answers":["{\"snippet\":\"Generally no opti...             1
# 997  [{"answers":["{\"snippet\":\"great benefits an...            31
# 998  [{"answers":["{\"snippet\":\"fun / down to ear...            11
# 999                                                NaN            19
#
#                     interviews_experience  \
# 0                                     NaN
# 1    [{"name":"Positive","value":"100%"}]
# 2                                     NaN
# 3                                     NaN
# 4    [{"name":"Negative","value":"100%"}]
# ..                                    ...
# 995  [{"name":"Positive","value":"100%"}]
# 996   [{"name":"Neutral","value":"100%"}]
# 997  [{"name":"Positive","value":"100%"}]
# 998                                   NaN
# 999  [{"name":"Positive","value":"100%"}]
#
#                                                    url
# 0    https://www.glassdoor.com/Overview/Working-at-...
# 1    https://www.glassdoor.com/Overview/Working-at-...
# 2    https://www.glassdoor.com/Overview/Working-at-...
# 3    https://www.glassdoor.com/Overview/Working-at-...
# 4    https://www.glassdoor.com/Overview/Working-at-...
# ..                                                 ...
# 995  https://www.glassdoor.com/Overview/Working-at-...
# 996  https://www.glassdoor.com/Overview/Working-at-...
# 997  https://www.glassdoor.com/Overview/Working-at-...
# 998  https://www.glassdoor.com/Overview/Working-at-...
# 999  https://www.glassdoor.com/Overview/Working-at-...
#
# [1000 rows x 47 columns]

# %%
df.describe()
# Out:
#                  id  ratings_overall  details_founded  \
# count  1.000000e+03      1000.000000       454.000000
# mean   1.836809e+06         3.755500      1988.524229
# std    1.506526e+06         0.761531        40.384008
# min    1.550000e+02         0.000000      1636.000000
# 25%    7.943355e+05         3.300000      1980.000000
# 50%    1.328070e+06         3.800000      2001.500000
# 75%    2.526258e+06         4.300000      2012.000000
# max    6.311675e+06         5.000000      2022.000000
#
#        ratings_career_opportunities  ratings_ceo_approval  \
# count                    1000.00000           1000.000000
# mean                        3.47250              0.351280
# std                         0.86304              0.422028
# min                         1.00000              0.000000
# 25%                         2.90000              0.000000
# 50%                         3.50000              0.000000
# 75%                         4.00000              0.810000
# max                         5.00000              1.000000
#
#        ratings_ceo_approval_count  ratings_compensation_benefits  \
# count                 1000.000000                    1000.000000
# mean                    14.166000                       3.419500
# std                     68.358608                       0.844075
# min                      0.000000                       1.000000
# 25%                      0.000000                       2.900000
# 50%                      0.000000                       3.500000
# 75%                      5.000000                       4.000000
# max                   1197.000000                       5.000000
#
#        ratings_cutlure_values  diversity_inclusion_score  \
# count             1000.000000                 492.000000
# mean                 3.643900                   3.789024
# std                  0.886854                   1.151799
# min                  1.000000                   1.000000
# 25%                  3.100000                   3.000000
# 50%                  3.700000                   4.000000
# 75%                  4.300000                   5.000000
# max                  5.000000                   5.000000
#
#        diversity_inclusion_count  ...  ratings_work_life_balance  \
# count                 935.000000  ...                1000.000000
# mean                   18.683422  ...                   3.605200
# std                    67.899601  ...                   0.849408
# min                     1.000000  ...                   1.000000
# 25%                     2.000000  ...                   3.000000
# 50%                     4.000000  ...                   3.700000
# 75%                    11.000000  ...                   4.200000
# max                   962.000000  ...                   5.000000
#
#        ratings_business_outlook  ratings_recommend_to_friend  salaries_count  \
# count                1000.00000                  1000.000000     1000.000000
# mean                    0.60009                     0.685790      103.130000
# std                     0.29802                     0.265166      651.099946
# min                     0.00000                     0.000000        0.000000
# 25%                     0.40000                     0.500000        5.000000
# 50%                     0.61000                     0.710000       13.000000
# 75%                     0.83000                     0.930000       35.250000
# max                     1.00000                     1.000000    13098.000000
#
#        interview_difficulty  interviews_count  benefits_count  jobs_count  \
# count            710.000000       1000.000000      649.000000   1000.0000
# mean               2.579155         10.762000       25.060092     46.8530
# std                0.699740         65.914202      146.594304    505.8092
# min                1.000000          0.000000        1.000000      0.0000
# 25%                2.000000          0.000000        2.000000      0.0000
# 50%                2.700000          1.000000        4.000000      0.0000
# 75%                3.000000          3.000000       10.000000      5.0000
# max                5.000000       1250.000000     2913.000000  11348.0000
#
#        photos_count  reviews_count
# count    318.000000    1000.000000
# mean       9.732704      68.133000
# std       18.188834     450.752554
# min        1.000000       1.000000
# 25%        1.000000       4.000000
# 50%        5.000000      10.000000
# 75%       10.000000      26.000000
# max      185.000000    9196.000000
#
# [8 rows x 21 columns]

# %%
df.company.unique()
# Out:
# array(['Brightlands',
#        'Ordine dei Medici Chirurghi e Odontoiatri Provincia di Caltanissetta',
#        'F&C Engineers', 'Minuteman Mortgage', 'Fathom Computing',
#        'Avant Gardner', 'Diocese of Palm Beach', 'Ascens Services',
#        'Jeanswest', 'Power Grads',
#        'Board of Certified Safety Professionals', 'Sophia Global',
#        'Trans-Matic Mfg', 'Mecklenberg County Public School District',
#        'Willoughby City Council', 'Progressive Irrigation',
#        'Super Car Guys', 'Deepblu', 'Eicoff', 'New Horizons (AK)',
#        'Skender', 'Mayfield Lavender ', 'Kitchen Craft', 'Genability',
#        'Dalkia UK', "Ecole Nationale de l'Aviation Civile",
#        '160 Driving Academy', 'TechNineties', 'Hospice of the Chesapeake',
#        'Department of National Defense', 'Home Trends & Design',
#        'Scanpoint Geomatics', 'Lumina Geophysical', 'PAL Line',
#        'Eden Ritchie Recruitment', 'Keith Huber Corporation',
#        'Contracts IT', 'Manatee County Emergency Communications Center',
#        'AdroitMinds Software Labs', 'SpecializedRx Products',
#        'Alamo Heights Independent School District', '365 Retail Markets',
#        'Method Recruiting', 'Tatvic Analytics',
#        'A Peace of Mind Home Care Solutions', 'Lambent',
#        'Las Vegas Day School', 'Denuo Source', '3YOURMIND', 'Octalsoft',
#        'Merlyn Industries', 'GUARD Service Bewa GmbH',
#        'Greater Good Health', 'Bender Group PR',
#        'Kansas State School for the Blind', 'Judith & Charles',
#        'Wi-Com Solutions', 'Green Air Environmental', 'Wave Aquatics',
#        'Perle Hotels Ltd', 'Cheng Xin', 'Play Dog Play', 'The GHS Group',
#        'Odournet', 'I.O. Metro', 'Reachdesk', 'Lendlease',
#        'Santa Barbara Polo & Racquet Club', 'Enseñalia',
#        'Selle Royal Group', 'Lebeda Mattress Factory',
#        'Industry Platform', 'Pizza Hotline',
#        'Law Offices of Daniel C. Consuegra', 'Fulfillment IQ',
#        'V Squared Events', 'Leading Edge Systems Richmond',
#        'Providence St Mel School', 'EMI', 'Cliffe Dekker Hofmeyr',
#        'MicroAssist', 'Colorado Athletic Club', 'Partnership Schools',
#        'Nobu Hospitality', 'Stonewater Partners', 'Forward Space',
#        'Alchemy Worx', 'Milyli', 'PayCore', 'EMC Business Solutions',
#        'TONSE Technologies', 'Vizz Media', 'L2TMedia',
#        'The Better Software Company', 'Camp Stone', 'Bolt Construction',
#        'UPilot', 'New York Kimchi', 'Local Table', 'Vertuo Conseil',
#        'CelestiaUK', 'J.R. Johnson, Inc.', 'Dalton Schools',
#        'KO Creative', 'Olivia', 'WyzMindz', 'Strides Software Solutions',
#        "Clackamas County Children's Commission", 'Dutton Group',
#        'Access Research Labs',
#        'Contoocook Valley Regional School District',
#        'Modern Niagara Group', 'Missouri Veterans Commission',
#        'Dexter Moren Associates', 'Adevinta', 'Air Control Systems',
#        'Bellarmine College Preparatory', 'MyFitnessPal',
#        'La Boulangerie de San Francisco', 'Convertus', "Charley's Angels",
#        'Springbok', 'Venice Toyota', 'Perfection Infoweb',
#        'G&L Healthcare Advisors', "Children's World Learning Center",
#        'A P Ventures', 'Lyons School District 103', 'Good Shepherd',
#        'easyApotheke', 'CAS Global', 'Academy', 'Silencer Central',
#        'Teehub', 'Small Business BC', 'Carl Finance GmbH',
#        'Fondazione Istituto Sacra Famiglia Onlus', 'Essential Logistics',
#        'Crescent View West Public Charter School',
#        'Summit Surgery Center', 'Dolist', 'IGS Security', 'Cloud 9 IDE',
#        'Westway Promotions', 'Black Pearl', 'Forest Stewardship Council',
#        'Medical Billing Management', 'Evans Industries', 'LB Water',
#        'Concurrent Technologies', 'Stepen Bradford Search', 'ROSHEN',
#        'St. Cloud Preparatory Academy', 'LiveMore Capital',
#        'Usher Transport', 'REM Sleep Labs', 'Rxperts Pharmacy',
#        'The Energy Collective', 'NEEDaFIXER', 'Pertica', 'Dutchict',
#        'E Sciences', 'Quality Liaison Services (Tennessee)', 'DP George',
#        'The Testament', 'Wesley College (Perth)', 'Safeway',
#        'Brooklyn Music School', 'Razoyo', 'American Air & Heat',
#        'Pathfinder Health Innovations', 'Monty Tech',
#        'Northwest College Support', 'MidNite Solar', 'Lynch Consultants',
#        'Eagle Marine Services', 'Public Sector Resourcing',
#        'Mr. Holmes Bakehouse', 'KinderWorld Education Group', 'Air Aroma',
#        'XanPool', 'x.ai', 'AppITron Solutions', 'Freeletics',
#        'McClenny Moseley & Associates',
#        'Working at NeworkRail Telecommunication',
#        'Jamestown Advanced Products', 'ViDoc', 'TEAM Technologies',
#        'Blalock Machinery and Equipment', 'Priority Dispatch, Inc.',
#        'Stats Perform', 'Housing Authority of Savannah',
#        'Sacred Heart Cathedral Preparatory',
#        'Diversified Investment Advisors', 'TOPS Infosolutions',
#        'Schafer Cullen Capital Management',
#        'Pinnacle Entertainment Group', 'Piedmont Retina Specialists',
#        'PaperHop', 'ETS Power Group', 'Breakr', 'Seoul Garden',
#        'future demand', 'RetroSuperFuture', 'Moog', 'Borlänge kommun',
#        'Workpillar', 'Click-Pack', 'The Advocate Program',
#        'Schedule Engine', 'Leaders Moving & Storage', 'StrategyCorps',
#        'Visiting Nurse Association of Kansas City',
#        'Raveneaux Country Club', 'AL Tayer', 'Pay it Forward Processing',
#        'Capital Markets Trading', 'True Capital Management',
#        'Breakout Capital Finance', 'East Bay Center',
#        'Hazelnuts Crêperie', 'SeniorAdom', 'Carbon (Nigeria)',
#        'Stafford Public Schools', 'Team One Credit Union',
#        'Rubin and Rudman', 'Surefire Local', 'ANC HomeHealth Services',
#        'Heath Consultants', 'Bryant & Stratton College',
#        'Anchin Block & Anchin', 'Luzerne County Community College',
#        'CodeYourFuture', 'Dinding Poultry',
#        'Antigua Public Utilities Authorities', 'Organizational Solutions',
#        'Wernle Youth & Family Treatment Center',
#        'Mattax Neu Prater Eye Center', 'Gatehouse Companies',
#        'Dick Scott Automotive Group', 'Road America Motor Club',
#        'Teltech', 'Schatz Publishing Group', 'Dr.cash', 'GRUPO SHOCK',
#        'Bulonfer SA', 'Dumont (Mexico)', 'Belterra Casino Resort',
#        'MRK InnoApps', 'Universidad de La Sabana', 'Nearshore Code',
#        'BCEN', 'SocketLabs', 'Mudpenny ', 'BWD MEDIA', 'Spec Engineering',
#        'Vitality Group', 'SearchLab', 'Parnassia Groep', 'ADOPT id PLM',
#        'Veritas Design Group', 'Reformhaus Engelhardt',
#        'ProSearch Strategies', 'Missing Link Security',
#        'Bridgetown Natural Foods', 'Kensington Bank', 'UniCredit Group',
#        'Ladder Now', 'Worcester Polytech', 'SNEF',
#        'Primetime Movers Portland', 'A3Ventures', 'Telenova Networks',
#        'NanoXplore', 'South Lyon Community Schools', 'TSi Geotechnical',
#        'The American Constitution Society', 'Dylan Powell Consulting',
#        'Telair (Australia)', 'EOLAS', 'Procer Automação e Sistemas',
#        'PD7 Technology', 'Terracap (Brazil)', 'Portonave', 'Avenue Hoche',
#        'Medanito', 'Universidade Federal de Pelotas (UFPEL)',
#        'Casino Buenos Aires', 'Hospital Santa Rosa', 'DW Software',
#        'FIEMT', 'Magic Hand Carwash', 'Hogeschool van Arnhem en Nijmegen',
#        'Green Standards', 'Wadhim Solutions', 'The Landings',
#        'Flagship CarWash Center', 'House of Hope Orlando',
#        "Mancini's Sleepworld", 'Northwestern Indiana Telephone Company',
#        'Foxtrot Market', '128 Air Refueling Wing',
#        'The Law Offices of Daniel Kim', 'Direct Business Lending',
#        'Westiform', 'Jones, Edmunds & Associates', 'Pebble Beach Company',
#        'Solar Turbines', 'Partner Communications', 'Vivino Group',
#        'Select POS & Peripherals', 'Fox Hills Golf & Banquet Center',
#        'VitalMed Systems and Solutions', 'The Care Group', 'imatia',
#        'Happy Hollow Park and Zoo', 'Company Watch', 'Nutrition Depot',
#        'Stone Soup Tech', 'Perfect Companion', 'Walton Enterprises',
#        'Emmi', 'Collective Haus', 'Landmark Property Management',
#        'T.O. Plastics', 'Naples Zoo', 'Kater', 'NATO', 'AvMed',
#        'Anansi Solutions', 'Atomic Interactions ', 'Restaurant Group',
#        'Costa Vida', 'Blair West', 'Illva Saronno',
#        'Miami-Dade Animal Services', 'Hedayah', 'Idealist.org',
#        'Deutscher Fachverlag GMBH',
#        'Nevada Department of Health & Human Services',
#        'Legends of Learning', 'Pfannenberg', 'Camp Greylock for Boys',
#        'ARCOA Group', 'FusionOps', 'Henrichsen',
#        'Rising Tide Interactive', 'Clyde Group', 'The Pizza Press',
#        'Al Ashram Contracting', 'KBL Cosmetics', 'Metro Truck Group',
#        'Reasonable Insurance Group', 'Codat',
#        'Association of Employment and Learning Providers',
#        'ENI de Tarbes', 'BioT', 'Associazione Diplomatici', 'Orange',
#        'EduBenchers', 'Bryan L. Salamone & Associates', 'Doyon',
#        'PrepBytes', 'Apigee', 'Opaa! Food Management',
#        'Golden Hill Post Acute Care', 'Tsakos Energy Navigation',
#        'Team Technology', 'Stockyards Station', 'Hinterland Studio',
#        'QueensCare Health Centers', 'M3 USA',
#        'First Stroke Mobile Swim School',
#        'Rhode Island Department of Corrections', 'Kyma Technologies',
#        'STA Travel', 'USA Vein Clinics', 'A-COM SECURITY', 'Etro',
#        'The Buckle', 'Treant Zorggroep', 'Jaipur Rugs', 'Utopia Deals',
#        'Human Rights Data Analysis Group', 'ole',
#        'St. Mark Catholic School', 'R L Fine Chem',
#        'Arkansas Secretary of State', 'Industrial Technology Services',
#        'Colisee', 'Kujawa Enterprises', 'Finnovate', 'Dezire Solutions',
#        'Torrey Holistics', 'Renaud’s Patisserie & Bistro', 'Edoxx',
#        'IDAX Data Solutions', 'MagicBell', 'Vanguard Car Rental',
#        'HealthFirst Family Care Center', 'Select Healthcare Group',
#        'Westex Security Services', 'Quest Inc', 'Canyon Pipeline',
#        'Adrienne Arsht Center', 'Mitten Building Products',
#        'Kansas City Repertory Theatre', 'Scriplogix', 'Customers Bank',
#        'Clean Air Task Force', 'OZNaturals', 'mymoneykarma', 'AVerMedia',
#        'ISB Global', 'Broadcat', 'XAM Consulting', 'FifthGear Plus',
#        'Hoamsy', 'Desert Rose Resort', 'Wildcard (WI)',
#        'Carroll County Animal Hospital', 'OEConnection', 'Axioned',
#        'National Vehicle Protection Services', 'Adventure Landing',
#        'iGo3D', 'Beatrix Restaurants', 'Lisle (IA)',
#        'Interstate Packaging', 'SmartStop Asset Management',
#        'Digital Video Systems', 'CDS Defence & Security', 'DoctorCare',
#        'MERKAL', 'Séntisis', 'Strater Hotel', 'Mesirow Financial',
#        'Optima Tax Relief ', 'Mighty', 'Riverside County Public Health',
#        'Vivienne Westwood', 'RIFT Tax Refunds', 'The Altenheim',
#        'Little Stars Preschool', 'Focus Resourcing', 'FetchBack',
#        'Jefferson Harmon & Associates', 'Great Northern Corporation',
#        'Giumarra Companies', 'Big Bazaar', 'Hotel Sogo', 'INCAS (Italy)',
#        'Parts Authority', 'Veteran Industries', 'Pointe Advisory',
#        'AdvantaClean Systems', 'FeedMob', 'dotloop', 'Askoll',
#        'Inspection Depot', 'Mosaic Smart Data', 'BEAST', 'Contec Global',
#        'Avoca', 'Bitmovin', 'ByteChek', 'Davis Archway Treatment Center',
#        'Montgomery County Fire & Rescue', 'W. M. Barr', 'TRQD',
#        'More Farm Stores', 'Oneness Control Panels', 'INEOS',
#        'MWT Architects', 'Animal Supply Company',
#        'Corporate Success Pte Ltd', "Badger Bob's Services", 'Soraa',
#        'Express Property Group', 'Legal.io', 'NVE Bank',
#        'Bright Future Management', 'Potamkin Automotive',
#        'Fédération interprofessionnelle de la santé du Québec',
#        'Michael W. Folonis Architects', 'Larcovi', 'Morningstar Mission',
#        'Duncan and Todd Group', 'Cargotec', "Nature's Best", 'mibanco',
#        'Lapithus Management', 'Richmond County School System',
#        'Field Nation', 'Communicorp Media', 'ClearPoint Services',
#        "Claire's Stores", 'ten24 Digital Solutions', 'Naf Naf',
#        'Indiana Botanic Gardens', 'Cloud Conformity', 'Imex Systems',
#        'Brella Productions', 'Vividly', 'BlueOrange Compliance',
#        'Hazelwick School', 'OrangeHRM', 'Spirited Gifts', 'Gerloff',
#        'Teacup Tech Systems', 'DMK & Associates', 'Med-Strategies',
#        'Therapy 2000', 'Central Medical Services of Westrock',
#        'IntelliSoft', "Glazer's", 'Big Jeff Online Inc', 'Scribe.ology',
#        'Buckeye Pacific', 'Mateeb Tech', 'Pacific Basin Shipping',
#        'Entando', 'All Pro Restoration', 'Ombudsman Educational Services',
#        'HealthLoop', 'Boman and Kemp Manufacturing', 'Norfin',
#        'CaptivateIQ', 'Accelerated Connections',
#        "AÉROPORTS DE LA COTE D'AZUR", 'Mrs. Fields Famous Brands',
#        'Imperial I.T', 'Noise Consulting Group', 'HECK Food',
#        'Compass Insurance Advisors', 'Craftsvilla.com', 'Bnext',
#        'Identity Management Service Organization',
#        'Breakaway Staffing Solutions', 'TESCA', 'BlackHorse Solutions',
#        'Joseph M. Wiedemann & Sons', 'The Arc of Dauphin County',
#        'Advanced Quality Lawn', 'Da Vinci Science Center',
#        'Tattooed Chef', 'Gardner Public School',
#        'Metadata Management Corporation', 'Pivot Systems',
#        'Astron e-Solutions', 'Value Kia', 'Crane School District',
#        'Exergy (US)', 'SEQENS', 'IT Governance', 'Maksat Technologies',
#        'Zuru Services', 'Oneida Indian Nation', 'Pathway to Recovery',
#        'City of Quincy, MA', 'Horus Music', 'Robert Darvas Associates',
#        'Berkeley Scott', '3S-Smart Software Solutions', 'EFT Source',
#        'Pacific Advanced Civil Engineering', 'Clayton Hotels',
#        'Main Street Hospitality', 'Mercat a la Planxa',
#        'The Credit Union Loan Source', 'Walled Lake Schools',
#        'The ExecRanks', 'pcm (Germany)', 'The Sachdev Group',
#        'Forrest Perkins', 'Alonia Healthcare Consulting', 'Servier',
#        'Temis HBJO', 'Lighthouse Property Management', 'IBISWorld',
#        'Stephen S. Wise Temple', 'STAR Translation Services', 'Energas',
#        'Nationale Suisse', 'Camber Spine Technologies',
#        'Nava Software Solutions', 'Plant Construction',
#        'Admedes Schuessler', 'Terra Firma', 'Claymont City Schools',
#        'IXOR Visual FX', 'Unik Systech Solutions', 'Lobster Place',
#        'CCME (Carolinas Center for Medical Excellence)',
#        'North Wellington Health Care', 'Niyantras',
#        'Li & Associates Design Studio', '\u200b\u200bNeuchâtel',
#        "Children's Receiving Home", 'Bellair Laser Clinic', 'Macfarlanes',
#        'MedStar EMS', 'Ville de Laval', 'Psoas Massage + Bodywork',
#        'Han River Technology', 'Salalem', 'Hilton Software', 'Omantel',
#        'Total Tech Pools & Leisure', 'Synoptics Technologies',
#        'Doc Popcorn', 'J D Shehadi', 'Town of Madison, Connecticut',
#        'The Whitestone Group', 'Wepro', 'GCC', 'Trafikverket',
#        'Graphhene Software', 'Cogent Biosciences',
#        'International Cinematographers Guild', 'ΙΜΕ Πληροφορική',
#        'US Foods', 'Lippo Malls Indonesia Retail Trust',
#        'Lillstreet Art Center', 'Grupo ConsulMed',
#        'American Samoa Department of Education', 'HydroDynamics',
#        'TreeTop Commons', 'Kiwi Wealth', 'Parasuco', 'Edibo', 'CubexO',
#        "Aunt Martha's Health & Wellness", 'Khoj Information Technology',
#        'Village of Tequesta', 'Firefly Communications',
#        'The House Next Door', 'Dinos Family Chip Shops',
#        'Career Channel (MY)', 'MRA Consulting Group',
#        'Express Lane Convenience Stores', 'Precision BioLogic',
#        'FracTracker Alliance', 'Resource Management', 'Anglia Homes',
#        'Pioneer Commercial Cleaning', 'Chika',
#        'Stratford Board of Education', 'J McCann & Co',
#        'Holy Trinity High School', 'Jones Networking', 'Izzi Telecom',
#        'RMS The Hospitality Cloud', 'McCann Tel Aviv',
#        'FHLB Indianapolis', 'Passage Bio',
#        'Acts Retirement-Life Communities', 'Herta Security',
#        'Residents Medical', 'Marble Slab', 'Paavu',
#        'Nicklaus Golf Club at LionsGate', 'Whitney Manor',
#        'Edgewood Manor', 'Evviva Trattoria', 'Dindinn',
#        'National Filter Media', 'Beta Insight Advisory',
#        'Fission Infotech', 'Sky Express Airlines', 'BIO RAW',
#        'Resource360 HR', 'Gold Coast Linen Services', 'Olive Tree',
#        "Let's Enkindle", 'Risk Management of Atlanta',
#        'X-Byte Enterprise Solutions', 'National Bank of Dominica',
#        'NDB (CA)', 'BeSpokeQA', 'Community Financial Services Bank',
#        "Trible's", 'Bird & Bird', 'Twa Panel Systems',
#        'Care For People Plus', 'Blood Centers of the Pacific',
#        'Kids for Less', 'Eagle Mark 4', 'Ville de Lausanne',
#        'Carnahan Proctor Cross', 'OneSpot', 'Engineered Network Systems',
#        'European Defence Agency', 'WealthWave', 'Volks Resources',
#        'YASH Industrial Solutions', 'CONET', 'Br Printers (CA)',
#        'ScaleArc', 'Social Deal', 'Dulcinea Farms', 'MBW',
#        'Esterline Landscape', 'Guthrie Theater',
#        'Saudi Electric Services Polytechnic',
#        'Aasheha Technology Services', 'BOXARR',
#        'Our Lady of the Angels Health', 'ITECCO', 'RTD Construction',
#        'NutriFormance', 'Bulger Veterinary Hospital',
#        'Aviation Medicine Advisory Service \u2003',
#        'Insurance Brokers of Arizona', 'City of Kelowna',
#        'Winnipeg Harvest', 'Testin', 'Hypergiant', 'Perfect Smile Braces',
#        'BHD Instrumentation', 'Bay Area Clinical Associates', 'Schmidt',
#        'Adlab Solutions', 'WanderOn', 'M&T Logistics', 'Groeneveld Groep',
#        'Lexus of Sacramento', 'Plastikon Industries', 'Adelman Travel',
#        'THOMASVILLE REGIONAL MEDICAL CENTER',
#        'Mountain View Regional Hospital', 'Foss Swim School',
#        'PA Treatment and Healing', 'Virginia Tech Services, Inc.',
#        'WorkSource', 'Smaartt Digital Consulting', 'Boutique Recruiting',
#        'Novo ProSo', 'Logan Data', 'AGP Group', 'TalentEgg',
#        'Marketing Management Analytics', 'Tempcool', 'UV Robots',
#        'Estateably', 'Brandywine Homes USA',
#        'Lorain/Medina Community Based Correctional Facility',
#        'Scribe Innovations', 'Mercari', 'Nova Flex LED', 'Otesaga',
#        'Voda Integrative Medical Clinic', 'Virtual Oplossing', 'Randoli',
#        'Pontchartrain Partners', ' Engel & Völkers St. Pete', 'Route 101',
#        'Schlatter Industries', 'Illuzions Unlimited',
#        'Kantonspolizei Zürich', 'SMC INDUSTRIES', 'UK Broadband',
#        'R Holding', 'Friso', 'Diva Salon and Spa', 'Original Cottages',
#        'Afriex', 'Fromm International', 'Wjys Tv 62',
#        'Night Shift Brewing', 'Revel', 'LEXINGTON CITY SCHOOLS',
#        'Technical Assurance', 'Integral Quality Care',
#        'Network Communications Inc', 'Sportmaster',
#        'Oconee County Schools', 'City of Toronto', 'Kriska', 'Unily',
#        'BIP', 'Rigkno', 'Suffolk County Department of Social Services',
#        'Paragon Innovations, Inc.', 'Synchrony Labs LLC',
#        'Anjali Mukerjee Health Total', 'orderbird', 'Somish Solutions',
#        'e-Merge Real Estate', 'Media-Soft', 'Virtucom', 'TA Aerospace',
#        'MHBC Planning', 'Asian Pacific Islander Legal Outreach',
#        'Rapid Rad', 'Platform Aerospace', 'ROYAL GROUP',
#        'Badminton School', 'Farm Radio International', 'CKD Galbraith',
#        'Harris Hill', 'Willard Powell', 'Costway', 'Art and Cook',
#        'S.B.Jain Institute of Technology, Management & Research',
#        'RCS Communications', "Simonson's Salon & Spa",
#        'JetBlue Technology Ventures', 'Meridian Solutions',
#        'Position Music', 'Leader Group', 'District of Lake Country',
#        'Bedford Nursing & Rehabilitation Center (NH)', '5874',
#        'SteelWave', 'Intellek', 'Abacus Therapies', 'Jaadu',
#        'Digital Media Services UK', '72Point', 'The Advance Group',
#        'California School Information Services',
#        'Supfina Machine Company', 'ProAssert', 'Wheeling Hospital',
#        'Free Yezidi Foundation', 'Sherwood Heights School',
#        'Epicor Software', 'Borochemie International',
#        'Cotmac Electronics (Michigan)', 'Toolcraft (WA)',
#        'Alameda County Library', 'Sapling',
#        'Phelan Hallinan Diamond and Jones',
#        'Community Care Cooperative\ufeff', 'Europace', 'Insite',
#        'Capstone Center for Rehabilitation and Nursing',
#        'Columbia Housing Authority', 'American Deposit Management',
#        'Louis Capital Markets', 'Escom', 'Chief Executives Organization',
#        "Holiday World & Splashin' Safari", 'Blue Canoe Properties',
#        'Simplaex', 'SkoolTree',
#        'State of North Carolina Department of the Secretary of State',
#        'The Tuesday Company', 'Knight-Swift Logistics',
#        'Wheeler Accountants', '1Market', 'Maven Search',
#        'Kittelson and Carpo Consulting', 'EEI Communications',
#        'Kaskaid Hospitality', 'Loan Factory',
#        'Engineered Casting Repair Service', 'Carroll Enterprises',
#        "Holly Hill Children's Services", 'Maxwell Chambers',
#        'Advanced World Systems', 'Another Broken Egg Cafe',
#        'BuildHr Management Consultants', 'Christus St. Patrick Hospital',
#        'Occtoo', 'Assystem France', 'Examarly', 'Ucla Recreation',
#        'NAPA Center', 'Alliiance', 'Brokers Alliance',
#        'Boom Media Global', 'Midland Plastics', 'iDeal Technology',
#        'Assured Care Services', 'Calyxt', 'Peoples Gas',
#        'Chipkins Puratos', 'ProjX', 'Grow My Cleaning', 'Attain',
#        'Family Rescue ', 'Hanison Construction',
#        'Skilled Craftsmen of Texas', 'ITgma', 'Care With LOVE',
#        'CPOA Global', 'The Landscape Group', "Al Gurg Leigh's Paints",
#        'Knifton Enterprises', 'NextGen.Net',
#        'Schwed, Adams, Sobel & McGinley', 'Five Points Washington',
#        'Studio PMG', 'Investors in People', 'TalentMarketplace', 'ET Net',
#        'Bonnie Brae', 'Coretechs Consulting', 'Foster Garvey PC',
#        'The PAC Group', 'Caffebene', 'Northeast Landscape Contractors',
#        'Termac', 'Tx3 Services',
#        'nternational Asbestos Testing Laboratories', 'Goodrich Maritime',
#        'Lawrence County Courthouse', 'Willowdale High School',
#        'Tempo-Team', 'Innovation Pavilion',
#        'Los Angeles County Public Defender', 'Love From Companies',
#        'Bidgely', 'Actionpoint (United Kingdom)', 'Pinkoi', 'Metaswitch',
#        'Hawk Training', 'Triniti Immigration', 'Bargain Hunt', 'Wrangler',
#        'iDevices', 'Access Sciences', 'RGB International',
#        'Arts with the Disabled Association Hong Kong', 'NEARiX',
#        'Ron Robinson', 'Stern At Home Therapy ',
#        'B.i.TEAM Gesellschaft für Softwareberatung', 'Echo Media Group',
#        'Ottopia Technologies', 'Stax Omega Diner & Bakery',
#        'Rhodium Group', 'Washington Community Action Network',
#        "Tam Kah Shark's Fin/Seafood",
#        "Lucile Packard Foundation for Children's Health", 'Arc American',
#        'Top Notch Consultants ', 'VIP', 'Thoht Delta', 'La Caille',
#        'Rocky Mountain Tech Team', 'Providence Englewood Charter School',
#        'Kempinski', 'The Undercarriage', 'Feral Interactive',
#        'Verve, a Credit Union',
#        'Ministry of Sustainability & the Environment of Singapore',
#        'Laragh Courseware', 'Consumentenbond', 'MGEN', 'DIALOG (Canada)',
#        'Kansas Legislative Post Audit',
#        'Lower Lights Christian Health Center', 'Visualforma',
#        'CNQC (South Pacific) Holding', 'Webculous',
#        'Winner’s Circle Pub, Grille & OTB',
#        'Oakley Union Elementary School District',
#        'Pristine Logistics & InfraProjects', 'AX CAPITAL Real Estate',
#        '10000.com', 'Nexus (London)', 'Virtual Guard', 'Pulse PEMF',
#        'Grand Canyon Brewing', 'Burden & Burden Marketing',
#        'WP BAKERYGROUP', 'Aiwyn', 'Scope', 'PC Housing', 'StaffQuick',
#        'Ebenus Design Solutions', 'Boone County Parks & Recreation',
#        'Pulaski County, AR', 'Colosseum Athletics',
#        'Spiegel Technologies', 'GANM (INDIA) IMPEX',
#        'Administration Personnel Services',
#        'Torry Harris Integration Solutions', 'Hunt Valley Contractors',
#        'Techved Consulting', 'Xpert Professional',
#        'Residences Senior Living', 'Market Square Jewelers',
#        'Halliday, Watkins & Mann', 'City of Tempe', 'FundyPros',
#        'Tuminds Social Media', 'ProTrainings', 'Novak Motors',
#        'Shelf Drilling', 'Brundage Management', 'Timuz', 'Midwest Arbor',
#        'HintonBurdick CPAs & Advisors',
#        'Orthopedic & Sports Physical Therapy Associates', 'A.Hak'],
#       dtype=object)

# %%
df.nunique()
# Out:
# timestamp                               9
# id                                   1000
# company                              1000
# ratings_overall                        40
# details_size                            8
# details_founded                       107
# details_type                           13
# country_code                           56
# company_type                            8
# url_jobs                             1000
# url_overview                         1000
# url_reviews                          1000
# benefits_url                         1000
# details_headquarters                  627
# region                                  5
# details_industry                      387
# details_revenue                        10
# details_website                       990
# interviews_url                        999
# photos_url                            999
# ratings_career_opportunities           38
# ratings_ceo_approval                   77
# ratings_ceo_approval_count             92
# ratings_compensation_benefits          37
# ratings_cutlure_values                 39
# diversity_inclusion_score              37
# diversity_inclusion_count              97
# ratings_senior_management              40
# ratings_work_life_balance              38
# ratings_business_outlook               93
# ratings_recommend_to_friend            90
# ratings_rated_ceo                     537
# competitors                           144
# salaries_url                          999
# salaries_count                        185
# career_opportunities_distribution     363
# url_faq                              1000
# interview_difficulty                   29
# interviews_count                       69
# benefits_count                         80
# jobs_count                             98
# photos                                318
# photos_count                           44
# faq                                   828
# reviews_count                         155
# interviews_experience                 152
# url                                   999
# dtype: int64

# %%
df.country_code.unique()
# Out:
# array(['NL', 'IT', 'US', 'IN', 'CI', 'AU', 'GB', 'TW', 'FR', 'CA', 'SG',
#        'DE', 'IE', 'ES', 'ZA', 'TR', 'NO', 'PH', 'NG', 'UA', 'NZ', 'SE',
#        'PL', 'AE', 'MY', 'AG', 'BR', 'AR', 'MX', 'CO', 'BO', 'PA', 'BE',
#        'ZW', 'CH', 'IL', 'TH', 'PT', nan, 'GR', 'AT', 'FI', 'PE', 'LU',
#        'PK', 'HK', 'ID', 'JO', 'OM', 'AS', 'DM', 'SA', 'CN', 'HR', 'CY',
#        'MK', 'VI'], dtype=object)

# %%
df.isnull().sum()
# Out:
# timestamp                              0
# id                                     0
# company                                0
# ratings_overall                        0
# details_size                           0
# details_founded                      546
# details_type                           0
# country_code                           6
# company_type                           0
# url_jobs                               0
# url_overview                           0
# url_reviews                            0
# benefits_url                           0
# details_headquarters                   1
# region                               650
# details_industry                     262
# details_revenue                        0
# details_website                       10
# interviews_url                         1
# photos_url                             1
# ratings_career_opportunities           0
# ratings_ceo_approval                   0
# ratings_ceo_approval_count             0
# ratings_compensation_benefits          0
# ratings_cutlure_values                 0
# diversity_inclusion_score            508
# diversity_inclusion_count             65
# ratings_senior_management              0
# ratings_work_life_balance              0
# ratings_business_outlook               0
# ratings_recommend_to_friend            0
# ratings_rated_ceo                    463
# competitors                           70
# salaries_url                           1
# salaries_count                         0
# career_opportunities_distribution      1
# url_faq                                0
# interview_difficulty                 290
# interviews_count                       0
# benefits_count                       351
# jobs_count                             0
# photos                               682
# photos_count                         682
# faq                                  172
# reviews_count                          0
# interviews_experience                290
# url                                    1
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                                      id  ratings_overall  details_founded  \
# id                             1.000000         0.180110         0.325168
# ratings_overall                0.180110         1.000000         0.138795
# details_founded                0.325168         0.138795         1.000000
# ratings_career_opportunities   0.178652         0.740732         0.215407
# ratings_ceo_approval          -0.300804         0.166701        -0.075499
# ratings_ceo_approval_count    -0.153168        -0.013924        -0.089655
# ratings_compensation_benefits  0.144082         0.699432         0.152132
# ratings_cutlure_values         0.170875         0.785402         0.193329
# diversity_inclusion_score      0.144617         0.532186         0.027122
# diversity_inclusion_count     -0.126439         0.000298        -0.054551
# ratings_senior_management      0.180696         0.788934         0.217025
# ratings_work_life_balance      0.138002         0.702613         0.214543
# ratings_business_outlook       0.138821         0.600244         0.129130
# ratings_recommend_to_friend    0.175135         0.744666         0.117015
# salaries_count                -0.121692        -0.010347        -0.096540
# interview_difficulty           0.049640         0.107386         0.085989
# interviews_count              -0.124460        -0.002247        -0.085753
# benefits_count                -0.133548         0.004091        -0.073840
# jobs_count                    -0.093773        -0.007209        -0.108810
# photos_count                  -0.177541         0.020169         0.000706
# reviews_count                 -0.124570        -0.013314        -0.093575
#
#                                ratings_career_opportunities  \
# id                                                 0.178652
# ratings_overall                                    0.740732
# details_founded                                    0.215407
# ratings_career_opportunities                       1.000000
# ratings_ceo_approval                               0.176174
# ratings_ceo_approval_count                         0.020932
# ratings_compensation_benefits                      0.730844
# ratings_cutlure_values                             0.801932
# diversity_inclusion_score                          0.510731
# diversity_inclusion_count                          0.033360
# ratings_senior_management                          0.811749
# ratings_work_life_balance                          0.681818
# ratings_business_outlook                           0.628834
# ratings_recommend_to_friend                        0.705752
# salaries_count                                    -0.005658
# interview_difficulty                               0.119021
# interviews_count                                   0.005539
# benefits_count                                     0.003820
# jobs_count                                        -0.007939
# photos_count                                       0.116599
# reviews_count                                     -0.004212
#
#                                ratings_ceo_approval  \
# id                                        -0.300804
# ratings_overall                            0.166701
# details_founded                           -0.075499
# ratings_career_opportunities               0.176174
# ratings_ceo_approval                       1.000000
# ratings_ceo_approval_count                 0.186421
# ratings_compensation_benefits              0.177746
# ratings_cutlure_values                     0.194812
# diversity_inclusion_score                  0.084042
# diversity_inclusion_count                  0.168510
# ratings_senior_management                  0.197796
# ratings_work_life_balance                  0.165347
# ratings_business_outlook                   0.166456
# ratings_recommend_to_friend                0.191934
# salaries_count                             0.109862
# interview_difficulty                      -0.041520
# interviews_count                           0.115207
# benefits_count                             0.111709
# jobs_count                                 0.076293
# photos_count                               0.123959
# reviews_count                              0.101374
#
#                                ratings_ceo_approval_count  \
# id                                              -0.153168
# ratings_overall                                 -0.013924
# details_founded                                 -0.089655
# ratings_career_opportunities                     0.020932
# ratings_ceo_approval                             0.186421
# ratings_ceo_approval_count                       1.000000
# ratings_compensation_benefits                    0.011869
# ratings_cutlure_values                           0.003312
# diversity_inclusion_score                       -0.019156
# diversity_inclusion_count                        0.613534
# ratings_senior_management                       -0.007973
# ratings_work_life_balance                        0.001413
# ratings_business_outlook                        -0.011532
# ratings_recommend_to_friend                     -0.002368
# salaries_count                                   0.785747
# interview_difficulty                            -0.008200
# interviews_count                                 0.858974
# benefits_count                                   0.672401
# jobs_count                                       0.537521
# photos_count                                     0.514222
# reviews_count                                    0.794038
#
#                                ratings_compensation_benefits  \
# id                                                  0.144082
# ratings_overall                                     0.699432
# details_founded                                     0.152132
# ratings_career_opportunities                        0.730844
# ratings_ceo_approval                                0.177746
# ratings_ceo_approval_count                          0.011869
# ratings_compensation_benefits                       1.000000
# ratings_cutlure_values                              0.725258
# diversity_inclusion_score                           0.514490
# diversity_inclusion_count                           0.040468
# ratings_senior_management                           0.732635
# ratings_work_life_balance                           0.674695
# ratings_business_outlook                            0.559851
# ratings_recommend_to_friend                         0.602596
# salaries_count                                      0.000080
# interview_difficulty                                0.155576
# interviews_count                                    0.006946
# benefits_count                                      0.013250
# jobs_count                                         -0.008344
# photos_count                                        0.102535
# reviews_count                                       0.000248
#
#                                ratings_cutlure_values  \
# id                                           0.170875
# ratings_overall                              0.785402
# details_founded                              0.193329
# ratings_career_opportunities                 0.801932
# ratings_ceo_approval                         0.194812
# ratings_ceo_approval_count                   0.003312
# ratings_compensation_benefits                0.725258
# ratings_cutlure_values                       1.000000
# diversity_inclusion_score                    0.647985
# diversity_inclusion_count                    0.019831
# ratings_senior_management                    0.888035
# ratings_work_life_balance                    0.803606
# ratings_business_outlook                     0.646182
# ratings_recommend_to_friend                  0.742025
# salaries_count                              -0.012714
# interview_difficulty                         0.112192
# interviews_count                            -0.002135
# benefits_count                               0.002135
# jobs_count                                  -0.008813
# photos_count                                 0.117657
# reviews_count                               -0.011893
#
#                                diversity_inclusion_score  \
# id                                              0.144617
# ratings_overall                                 0.532186
# details_founded                                 0.027122
# ratings_career_opportunities                    0.510731
# ratings_ceo_approval                            0.084042
# ratings_ceo_approval_count                     -0.019156
# ratings_compensation_benefits                   0.514490
# ratings_cutlure_values                          0.647985
# diversity_inclusion_score                       1.000000
# diversity_inclusion_count                      -0.000352
# ratings_senior_management                       0.597055
# ratings_work_life_balance                       0.520580
# ratings_business_outlook                        0.334644
# ratings_recommend_to_friend                     0.474287
# salaries_count                                 -0.002968
# interview_difficulty                            0.004273
# interviews_count                               -0.024426
# benefits_count                                 -0.021193
# jobs_count                                     -0.085297
# photos_count                                    0.169499
# reviews_count                                  -0.016049
#
#                                diversity_inclusion_count  ...  \
# id                                             -0.126439  ...
# ratings_overall                                 0.000298  ...
# details_founded                                -0.054551  ...
# ratings_career_opportunities                    0.033360  ...
# ratings_ceo_approval                            0.168510  ...
# ratings_ceo_approval_count                      0.613534  ...
# ratings_compensation_benefits                   0.040468  ...
# ratings_cutlure_values                          0.019831  ...
# diversity_inclusion_score                      -0.000352  ...
# diversity_inclusion_count                       1.000000  ...
# ratings_senior_management                      -0.003372  ...
# ratings_work_life_balance                       0.015239  ...
# ratings_business_outlook                        0.000121  ...
# ratings_recommend_to_friend                     0.020812  ...
# salaries_count                                  0.474537  ...
# interview_difficulty                            0.029645  ...
# interviews_count                                0.501888  ...
# benefits_count                                  0.349612  ...
# jobs_count                                      0.146279  ...
# photos_count                                    0.316854  ...
# reviews_count                                   0.405079  ...
#
#                                ratings_work_life_balance  \
# id                                              0.138002
# ratings_overall                                 0.702613
# details_founded                                 0.214543
# ratings_career_opportunities                    0.681818
# ratings_ceo_approval                            0.165347
# ratings_ceo_approval_count                      0.001413
# ratings_compensation_benefits                   0.674695
# ratings_cutlure_values                          0.803606
# diversity_inclusion_score                       0.520580
# diversity_inclusion_count                       0.015239
# ratings_senior_management                       0.773244
# ratings_work_life_balance                       1.000000
# ratings_business_outlook                        0.555660
# ratings_recommend_to_friend                     0.687776
# salaries_count                                 -0.011762
# interview_difficulty                            0.081271
# interviews_count                               -0.009101
# benefits_count                                 -0.004702
# jobs_count                                     -0.015466
# photos_count                                    0.102241
# reviews_count                                  -0.013569
#
#                                ratings_business_outlook  \
# id                                             0.138821
# ratings_overall                                0.600244
# details_founded                                0.129130
# ratings_career_opportunities                   0.628834
# ratings_ceo_approval                           0.166456
# ratings_ceo_approval_count                    -0.011532
# ratings_compensation_benefits                  0.559851
# ratings_cutlure_values                         0.646182
# diversity_inclusion_score                      0.334644
# diversity_inclusion_count                      0.000121
# ratings_senior_management                      0.662727
# ratings_work_life_balance                      0.555660
# ratings_business_outlook                       1.000000
# ratings_recommend_to_friend                    0.653618
# salaries_count                                -0.030249
# interview_difficulty                           0.124623
# interviews_count                              -0.022371
# benefits_count                                -0.016886
# jobs_count                                    -0.015802
# photos_count                                   0.080106
# reviews_count                                 -0.026161
#
#                                ratings_recommend_to_friend  salaries_count  \
# id                                                0.175135       -0.121692
# ratings_overall                                   0.744666       -0.010347
# details_founded                                   0.117015       -0.096540
# ratings_career_opportunities                      0.705752       -0.005658
# ratings_ceo_approval                              0.191934        0.109862
# ratings_ceo_approval_count                       -0.002368        0.785747
# ratings_compensation_benefits                     0.602596        0.000080
# ratings_cutlure_values                            0.742025       -0.012714
# diversity_inclusion_score                         0.474287       -0.002968
# diversity_inclusion_count                         0.020812        0.474537
# ratings_senior_management                         0.752516       -0.027873
# ratings_work_life_balance                         0.687776       -0.011762
# ratings_business_outlook                          0.653618       -0.030249
# ratings_recommend_to_friend                       1.000000       -0.009676
# salaries_count                                   -0.009676        1.000000
# interview_difficulty                              0.112943       -0.008124
# interviews_count                                 -0.005847        0.933664
# benefits_count                                    0.008579        0.912416
# jobs_count                                       -0.009831        0.678928
# photos_count                                      0.095079        0.532367
# reviews_count                                    -0.011183        0.963146
#
#                                interview_difficulty  interviews_count  \
# id                                         0.049640         -0.124460
# ratings_overall                            0.107386         -0.002247
# details_founded                            0.085989         -0.085753
# ratings_career_opportunities               0.119021          0.005539
# ratings_ceo_approval                      -0.041520          0.115207
# ratings_ceo_approval_count                -0.008200          0.858974
# ratings_compensation_benefits              0.155576          0.006946
# ratings_cutlure_values                     0.112192         -0.002135
# diversity_inclusion_score                  0.004273         -0.024426
# diversity_inclusion_count                  0.029645          0.501888
# ratings_senior_management                  0.093107         -0.017827
# ratings_work_life_balance                  0.081271         -0.009101
# ratings_business_outlook                   0.124623         -0.022371
# ratings_recommend_to_friend                0.112943         -0.005847
# salaries_count                            -0.008124          0.933664
# interview_difficulty                       1.000000          0.004082
# interviews_count                           0.004082          1.000000
# benefits_count                             0.007234          0.905119
# jobs_count                                -0.047314          0.560120
# photos_count                               0.059187          0.559746
# reviews_count                             -0.009780          0.960760
#
#                                benefits_count  jobs_count  photos_count  \
# id                                  -0.133548   -0.093773     -0.177541
# ratings_overall                      0.004091   -0.007209      0.020169
# details_founded                     -0.073840   -0.108810      0.000706
# ratings_career_opportunities         0.003820   -0.007939      0.116599
# ratings_ceo_approval                 0.111709    0.076293      0.123959
# ratings_ceo_approval_count           0.672401    0.537521      0.514222
# ratings_compensation_benefits        0.013250   -0.008344      0.102535
# ratings_cutlure_values               0.002135   -0.008813      0.117657
# diversity_inclusion_score           -0.021193   -0.085297      0.169499
# diversity_inclusion_count            0.349612    0.146279      0.316854
# ratings_senior_management           -0.012502   -0.012583      0.092054
# ratings_work_life_balance           -0.004702   -0.015466      0.102241
# ratings_business_outlook            -0.016886   -0.015802      0.080106
# ratings_recommend_to_friend          0.008579   -0.009831      0.095079
# salaries_count                       0.912416    0.678928      0.532367
# interview_difficulty                 0.007234   -0.047314      0.059187
# interviews_count                     0.905119    0.560120      0.559746
# benefits_count                       1.000000    0.443713      0.652617
# jobs_count                           0.443713    1.000000      0.193969
# photos_count                         0.652617    0.193969      1.000000
# reviews_count                        0.962111    0.556249      0.599601
#
#                                reviews_count
# id                                 -0.124570
# ratings_overall                    -0.013314
# details_founded                    -0.093575
# ratings_career_opportunities       -0.004212
# ratings_ceo_approval                0.101374
# ratings_ceo_approval_count          0.794038
# ratings_compensation_benefits       0.000248
# ratings_cutlure_values             -0.011893
# diversity_inclusion_score          -0.016049
# diversity_inclusion_count           0.405079
# ratings_senior_management          -0.022320
# ratings_work_life_balance          -0.013569
# ratings_business_outlook           -0.026161
# ratings_recommend_to_friend        -0.011183
# salaries_count                      0.963146
# interview_difficulty               -0.009780
# interviews_count                    0.960760
# benefits_count                      0.962111
# jobs_count                          0.556249
# photos_count                        0.599601
# reviews_count                       1.000000
#
# [21 rows x 21 columns]

# %%
df.region.unique()
# Out:
# array(['EU', nan, 'AS', 'AF', 'OC', 'SA'], dtype=object)
